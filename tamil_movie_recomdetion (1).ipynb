# %% [markdown]
# # Develop a movie recommendation model using the scikit-learn library in python. Refer dataset
# https://github.com/rashida048/Some-NLP-Projects/blob/master/movie_dataset.csv

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("Tamil_movies_dataset.csv")

# %%
data
# Out:
#              MovieName   Genre  Rating              Director  \
# 0           Mouna Guru  Action     7.7          Santha Kumar
# 1          7 Aum Arivu  Action     6.2       A.R. Murugadoss
# 2     Vaagai Sooda Vaa  Comedy     8.0           A. Sarkunam
# 3             Mankatha  Action     7.6         Venkat Prabhu
# 4     Kanchana: Muni 2  Comedy     6.5  Lawrence Raghavendra
# ..                 ...     ...     ...                   ...
# 324  Dhilluku Dhuddu 2  Comedy     5.3               Rambala
# 325                Dev  Action     4.8    Rajath Ravishankar
# 326  Charlie Chaplin 2  Comedy     3.8    Sakthi Chidambaram
# 327              Petta  Action     7.3      Karthik Subbaraj
# 328           Viswasam  Action     6.7                  Siva
#
#                     Actor  PeopleVote  Year  Hero_Rating  movie_rating  \
# 0               Arulnithi         746  2011            8             8
# 1                  Suriya        9479  2011            9             9
# ...

# %%
data.tail(50)
# Out:
#                          MovieName      Genre  Rating                Director  \
# 279               Nerkonda Paarvai     Action     8.2               H. Vinoth
# 280                        Jackpot     Action     5.2                 Kalyaan
# 281                             A1     Comedy     5.0              K. Johnson
# 282                           Aame      Drama     6.3            Rathna Kumar
# 283                 Kadaram Kondan     Action     5.7         Rajesh M. Selva
# 284          Sivappu Manjal Pachai     Action     7.1                    Sasi
# 285                         Gurkha     Action     4.7               Sam Anton
# 286        Vennila Kabaddi Kuzhu 2     Action     5.1           Selva Sekaran
# 287        Bodhai Yeri Budhi Maari      Drama     6.6                 Chandru
# 288                     Kalavani 2     Comedy     4.0             A. Sarkunam
# 289                      Raatchasi      Drama     7.3           Sy Gowthamraj
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329 entries, 0 to 328
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   MovieName       329 non-null    object
#  1   Genre           329 non-null    object
#  2   Rating          329 non-null    float64
#  3   Director        329 non-null    object
#  4   Actor           329 non-null    object
#  5   PeopleVote      329 non-null    int64
#  6   Year            329 non-null    int64
#  7   Hero_Rating     329 non-null    int64
#  8   movie_rating    329 non-null    int64
#  9   content_rating  329 non-null    float64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 25.8+ KB

# %%
data.describe()
# Out:
#            Rating    PeopleVote         Year  Hero_Rating  movie_rating  \
# count  329.000000    329.000000   329.000000   329.000000    329.000000
# mean     6.443161   7372.607903  2016.562310     6.793313      8.139818
# std      1.403835  14380.829757     2.142039     1.959923      0.760232
# min      1.200000      7.000000  2011.000000     1.000000      6.000000
# 25%      5.600000    455.000000  2015.000000     5.000000      8.000000
# 50%      6.700000   1320.000000  2017.000000     7.000000      8.000000
# 75%      7.500000   5907.000000  2018.000000     8.000000      9.000000
# max      9.000000  71418.000000  2019.000000    10.000000     10.000000
#
#        content_rating
# count      329.000000
# mean         7.125431
# std          0.856000
# min          4.300000
# 25%          6.666667
# 50%          7.200000
# 75%          7.766667
# max          8.766667

# %%
data.isnull().sum()
# Out:
# MovieName         0
# Genre             0
# Rating            0
# Director          0
# Actor             0
# PeopleVote        0
# Year              0
# Hero_Rating       0
# movie_rating      0
# content_rating    0
# dtype: int64

# %%
data.columns
# Out:
# Index(['MovieName', 'Genre', 'Rating', 'Director', 'Actor', 'PeopleVote',
#        'Year', 'Hero_Rating', 'movie_rating', 'content_rating'],
#       dtype='object')

# %% [markdown]
# # Add data to  Existing dataset

# %%
import pandas as pd

data = [
    ['Ye Maaya Chesave', 'Romance', 7.7, 'Gautham Menon', 'Naga Chaitanya', 10772, 2010, 7.4, 7.7, 'U'],
    ['Eega', 'Fantasy', 7.8, 'S.S. Rajamouli', 'Nani', 29835, 2012, 7.6, 7.8, 'U'],
    ['Neethaane En Ponvasantham', 'Romance', 6.5, 'Gautham Menon', 'Jiiva', 2645, 2012, 6.5, 6.5, 'U'],
    ['Attarintiki Daredi', 'Action, Drama', 7.7, 'Trivikram Srinivas', 'Pawan Kalyan', 18020, 2013, 7.5, 7.7, 'U'],
    ['Manam', 'Comedy, Drama', 8.0, 'Vikram K. Kumar', 'Akkineni Nageswara Rao, Nagarjuna Akkineni', 11347, 2014, 8.0, 8.0, 'U'],
    ['Thanga Magan', 'Action, Drama', 6.0, 'Velraj', 'Dhanush', 2518, 2015, 6.0, 6.0, 'U'],
    ['Theri', 'Action, Drama', 7.2, 'Atlee Kumar', 'Joseph Vijay', 15573, 2016, 7.0, 7.2, 'U/A'],
    ['A Aa', 'Comedy, Drama', 7.0, 'Trivikram Srinivas', 'Nithiin', 6321, 2016, 6.9, 7.0, 'U'],
    ['Janatha Garage', 'Action, Drama', 7.2, 'Koratala Siva', 'Mohanlal', 6616, 2016, 7.1, 7.2, 'U/A'],
    ['Mersal', 'Action, Drama', 7.6, 'Atlee Kumar', 'Joseph Vijay', 18224, 2017, 7.4, 7.6, 'U/A'],
    ['Rangasthalam', 'Action, Drama', 8.3, 'Sukumar', 'Ram Charan', 31612, 2018, 8.2, 8.3, 'U/A'],
    ['Majili', 'Drama, Romance', 7.1, 'Shiva Nirvana', 'Naga Chaitanya, Divyansha Kaushik', 6914, 2019, 6.9, 7.1, 'U/A'],
    ['Oh! Baby', 'Comedy, Drama', 7.3, 'Nandini Reddy', 'Lakshmi', 2688, 2019, 7.2, 7.3, 'U'],
    ['Jaanu', 'Drama, Romance', 7.5, 'C. Prem Kumar', 'Sharwanand', 3358, 2020, 7.3, 7.5, 'U'],
    ['Moscowin Kavery', 'Romance, Drama', 5.2, 'Ravi Varman', 'Rahul Ravindran', 203, 2010, 5.1, 5.2, 'U'],
    ['Dookudu', 'Action, Comedy', 7.5, 'Srinu Vaitla', 'Mahesh Babu', 11276, 2011, 7.4, 7.5, 'U/A'],
    ['Yeto Vellipoyindhi Manasu', 'Romance', 5.9, 'Gautham Menon', 'Nani', 1361, 2012, 5.8, 5.9, 'U'],
    ['Seethamma Vakitlo Sirimalle Chettu', 'Drama', 7.6, 'Srikanth Addala', 'Venkatesh, Mahesh Babu', 6477, 2013, 7.4, 7.6, 'U'],
    ['Ramayya Vasthavayya', 'Action, Drama', 5.6, 'Harish Shankar', 'Jr NTR', 3062, 2013, 5.5, 5.6, 'U/A'],
    ['Alludu Seenu', 'Action, Comedy', 4.7, 'V. V. Vinayak', 'Bellamkonda Sreenivas', 438, 2014, 4.6, 4.7, 'U/A'],
    ['Anjaan', 'Action, Drama', 5.2, 'N. Lingusamy', 'Suriya', 5189, 2014, 5.0, 5.2, 'U/A'],
    ['Kaththi', 'Action, Drama', 7.9, 'A.R. Murugadoss', 'Joseph Vijay', 18073, 2014, 7.7, 7.9, 'U/A'],
    ['S/O Satyamurthy', 'Action, Drama', 6.7, 'Trivikram Srinivas', 'Allu Arjun', 6619, 2015, 6.5, 6.7, 'U/A'],
    ['10 Endrathukulla', 'Action, Thriller', 5.2, 'Vijay Milton', 'Vikram', 2271, 2015, 5.1, 5.2, 'U/A'],
    ['Bangalore Naatkal', 'Comedy, Drama', 6.0, 'Bommarillu Bhaskar', 'Arya', 1615, 2016, 5.9, 6.0, 'U'],
    ['Irumbu Thirai', 'Action, Thriller', 7.7, 'P.S. Mithran', 'Vishal', 6359, 2018, 7.5, 7.7, 'U/A'],
    ['Super Deluxe', 'Comedy, Drama', 8.4, 'Thiagarajan Kumararaja', 'Vijay Sethupathi', 12707, 2019, 8.2, 8.4, 'A']
]

columns = ['MovieName', 'Genre', 'Rating', 'Director', 'Actor', 'PeopleVote', 'Year', 'Hero_Rating', 'movie_rating', 'content_rating']

df = pd.DataFrame(data, columns=columns)

# %%
df
# Out:
#                              MovieName             Genre  Rating  \
# 0                     Ye Maaya Chesave           Romance     7.7
# 1                                 Eega           Fantasy     7.8
# 2            Neethaane En Ponvasantham           Romance     6.5
# 3                   Attarintiki Daredi     Action, Drama     7.7
# 4                                Manam     Comedy, Drama     8.0
# 5                         Thanga Magan     Action, Drama     6.0
# 6                                Theri     Action, Drama     7.2
# 7                                 A Aa     Comedy, Drama     7.0
# 8                       Janatha Garage     Action, Drama     7.2
# 9                               Mersal     Action, Drama     7.6
# 10                        Rangasthalam     Action, Drama     8.3
# 11                              Majili    Drama, Romance     7.1
# 12                            Oh! Baby     Comedy, Drama     7.3
# ...

# %%
df.to_csv('movie_data.csv', index=False)

# %%
import pandas as pd


dataset1 = pd.read_csv('Tamil_movies_dataset.csv')
dataset2 = pd.read_csv('movie_data.csv')

concatenated_dataset = pd.concat([dataset1, dataset2], ignore_index=True)

# %%
concatenated_dataset
# Out:
#              MovieName             Genre  Rating                Director  \
# 0           Mouna Guru            Action     7.7            Santha Kumar
# 1          7 Aum Arivu            Action     6.2         A.R. Murugadoss
# 2     Vaagai Sooda Vaa            Comedy     8.0             A. Sarkunam
# 3             Mankatha            Action     7.6           Venkat Prabhu
# 4     Kanchana: Muni 2            Comedy     6.5    Lawrence Raghavendra
# ..                 ...               ...     ...                     ...
# 351    S/O Satyamurthy     Action, Drama     6.7      Trivikram Srinivas
# 352   10 Endrathukulla  Action, Thriller     5.2            Vijay Milton
# 353  Bangalore Naatkal     Comedy, Drama     6.0      Bommarillu Bhaskar
# 354      Irumbu Thirai  Action, Thriller     7.7            P.S. Mithran
# 355       Super Deluxe     Comedy, Drama     8.4  Thiagarajan Kumararaja
#
#                     Actor  PeopleVote  Year  Hero_Rating  movie_rating  \
# ...

# %% [markdown]
# # to check data is clean or not

# %%
print("First few rows of the dataset:")
concatenated_dataset.head()
# Out:
# First few rows of the dataset:
#           MovieName   Genre  Rating              Director  \
# 0        Mouna Guru  Action     7.7          Santha Kumar
# 1       7 Aum Arivu  Action     6.2       A.R. Murugadoss
# 2  Vaagai Sooda Vaa  Comedy     8.0           A. Sarkunam
# 3          Mankatha  Action     7.6         Venkat Prabhu
# 4  Kanchana: Muni 2  Comedy     6.5  Lawrence Raghavendra
#
#                   Actor  PeopleVote  Year  Hero_Rating  movie_rating  \
# 0             Arulnithi         746  2011          8.0           8.0
# 1                Suriya        9479  2011          9.0           9.0
# 2                 Vimal       14522  2011          8.0           7.0
# 3           Ajith Kumar       12276  2011          6.0           8.0
# 4  Lawrence Raghavendra        1044  2011          8.0           9.0
#
#   content_rating
# 0            7.9
# 1       8.066667
# 2       7.666667
# 3            7.2
# 4       7.833333

# %%
print("Summary statistics of numerical columns:")
concatenated_dataset.describe()
# Out:
# Summary statistics of numerical columns:
#            Rating    PeopleVote         Year  Hero_Rating  movie_rating
# count  356.000000    356.000000   356.000000   356.000000    356.000000
# mean     6.478371   7493.485955  2016.432584     6.791292      8.046348
# std      1.385075  14013.107370     2.242598     1.904704      0.850394
# min      1.200000      7.000000  2010.000000     1.000000      4.700000
# 25%      5.600000    507.500000  2015.000000     5.000000      7.700000
# 50%      6.700000   1452.000000  2017.000000     7.000000      8.000000
# 75%      7.525000   6719.750000  2018.000000     8.000000      9.000000
# max      9.000000  71418.000000  2020.000000    10.000000     10.000000

# %%
print("Checking for missing values:")
concatenated_dataset.isnull().sum()
# Out:
# Checking for missing values:
# MovieName         0
# Genre             0
# Rating            0
# Director          0
# Actor             0
# PeopleVote        0
# Year              0
# Hero_Rating       0
# movie_rating      0
# content_rating    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
print("Visualizations (Histogram of numerical columns")
numerical_cols = concatenated_dataset.select_dtypes(include=['float64', 'int64']).columns
for col in numerical_cols:
    plt.figure(figsize=(8, 6))
    sns.histplot(concatenated_dataset[col], kde=True)
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# Visualizations (Histogram of numerical columns

# %%
print("Data consistency (Checking unique values in categorical columns")
categorical_cols = concatenated_dataset.select_dtypes(include=['object']).columns
for col in categorical_cols:
    print(f"\nUnique values in {col}:")
    print(concatenated_dataset[col].unique())
# Out:
# Data consistency (Checking unique values in categorical columns
#
# Unique values in MovieName:
# ['Mouna Guru' '7 Aum Arivu' 'Vaagai Sooda Vaa' 'Mankatha'
#  'Kanchana: Muni 2' 'Deiva Thirumagal' 'Vaanam' 'Ko' 'Payanam'
#  'Yutham Sei' 'Aadukalam' 'Naduvula Konjam Pakkatha Kaanom' 'Thuppakki'
#  'Pizza' 'Naan' 'The Fly' 'Kalakalappu' 'Vazhakku Enn 18/9' 'Kumki'
#  'Neethaane En Ponvasantham' 'Thalaimuraigal' 'Biriyani'
#  'Ivan Veramaathiri' 'Kalyana Samayal Saadham' 'Irandam Ulagam'
#  'Pandiya Naadu' 'Arrambam' 'Onaayum Aattukkuttiyum' 'Raja Rani'
#  '6 Candles' 'Moodar Koodam' 'Varuthapadatha Valibar Sangam'
#  'Thanga Meengal' 'Aadhalal Kadhal Seiveer' 'Maryan' 'Singam 2'
#  'Theeya Velai Seiyyanum Kumaru' 'Neram' 'Soodhu Kavvum' 'Ethir Neechal'
#  'Kedi Billa Killadi Ranga' 'Paradesi' 'Kaakkaa Muttai' 'Kayal' 'Pisasu'
#  'Lingaa' 'Kaaviya Thalaivan' 'Kaththi' 'Jeeva' 'Madras'
#  'Kathai Thiraikathai Vasanam Iyakkam' 'Jigarthanda'
# ...

# %%
print("data type of coloumns")
data_types = concatenated_dataset.dtypes
print("Data Types:\n", data_types)
# Out:
# data type of coloumns
# Data Types:
#  MovieName          object
# Genre              object
# Rating            float64
# Director           object
# Actor              object
# PeopleVote          int64
# Year                int64
# Hero_Rating       float64
# movie_rating      float64
# content_rating     object
# dtype: object

# %%
duplicate_rows = concatenated_dataset.duplicated().sum()
print("Number of duplicate rows:", duplicate_rows)
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# # to find outliers

# %%
from scipy import stats

# Select numerical columns
numerical_columns = ['Rating', 'PeopleVote', 'Year', 'Hero_Rating', 'movie_rating', 'content_rating']

# Convert non-numeric values to NaN
for column in numerical_columns:
    concatenated_dataset[column] = pd.to_numeric(concatenated_dataset[column], errors='coerce')

# Calculate z-scores for each numerical column
z_scores = {}
for column in numerical_columns:
    z_scores[column] = stats.zscore(concatenated_dataset[column].dropna())

# Check for extreme z-score values
extreme_z_scores = {}
for column, scores in z_scores.items():
    extreme_z_scores[column] = sum((scores > 3) | (scores < -3))

print("Number of extreme z-scores for each column:")
print(extreme_z_scores)
# Out:
# Number of extreme z-scores for each column:
# {'Rating': 3, 'PeopleVote': 13, 'Year': 0, 'Hero_Rating': 4, 'movie_rating': 4, 'content_rating': 3}

# %% [markdown]
# # as per outlier clean the data

# %% [markdown]
# # 1.Remove Outliers

# %%
cleaned_data = concatenated_dataset[(concatenated_dataset['PeopleVote'] <= 3) & 
                                    (concatenated_dataset['Hero_Rating'] <= 3) & 
                                    (concatenated_dataset['movie_rating'] <= 3)]

# %% [markdown]
# # 2.Winsorization

# %%
from scipy.stats.mstats import winsorize
winsorized_data = concatenated_dataset.copy()
winsorized_data['PeopleVote'] = winsorize(winsorized_data['PeopleVote'], limits=[0.05, 0.05])
winsorized_data['Hero_Rating'] = winsorize(winsorized_data['Hero_Rating'], limits=[0.05, 0.05])
winsorized_data['movie_rating'] = winsorize(winsorized_data['movie_rating'], limits=[0.05, 0.05])

# %% [markdown]
# # 3.Transformations

# %%
import numpy as np
transformed_data = concatenated_dataset.copy()
transformed_data['PeopleVote'] = np.log1p(transformed_data['PeopleVote'])
transformed_data['Hero_Rating'] = np.log1p(transformed_data['Hero_Rating'])
transformed_data['movie_rating'] = np.log1p(transformed_data['movie_rating'])

# %% [markdown]
# # 4.Data Imputation

# %%
imputed_data = concatenated_dataset.copy()
imputed_data['PeopleVote'].fillna(imputed_data['PeopleVote'].median(), inplace=True)
imputed_data['Hero_Rating'].fillna(imputed_data['Hero_Rating'].median(), inplace=True)
imputed_data['movie_rating'].fillna(imputed_data['movie_rating'].median(), inplace=True)

# %% [markdown]
# # 5.Model-based Approaches

# %%
from sklearn.ensemble import IsolationForest
outlier_detector = IsolationForest(contamination=0.05)  
outliers = outlier_detector.fit_predict(concatenated_dataset[['PeopleVote', 'Hero_Rating', 'movie_rating']])
cleaned_data = concatenated_dataset[outliers != -1]

# %% [markdown]
# # new z-score

# %%
from scipy import stats
from scipy.stats.mstats import winsorize
import numpy as np


cleaned_numerical_columns = ['Rating', 'PeopleVote', 'Year', 'Hero_Rating', 'movie_rating', 'content_rating']


cleaned_data.loc[:, 'PeopleVote_winsorized'] = winsorize(cleaned_data['PeopleVote'], limits=[0.01, 0.01]).copy()


cleaned_data.loc[:, 'PeopleVote_log'] = np.log(cleaned_data['PeopleVote_winsorized'] + 1).copy() 



cleaned_z_scores = {}
for column in cleaned_numerical_columns:
    if column == 'PeopleVote':
        cleaned_z_scores[column] = stats.zscore(cleaned_data['PeopleVote_log'].dropna())
    else:
        cleaned_z_scores[column] = stats.zscore(cleaned_data[column].dropna())

# Check for extreme z-score values in the cleaned dataset
cleaned_extreme_z_scores = {}
for column, scores in cleaned_z_scores.items():
    cleaned_extreme_z_scores[column] = sum((scores > 3) | (scores < -3))

print("Number of extreme z-scores for each column in the cleaned dataset:")
print(cleaned_extreme_z_scores)
# Out:
# Number of extreme z-scores for each column in the cleaned dataset:
# {'Rating': 4, 'PeopleVote': 0, 'Year': 0, 'Hero_Rating': 2, 'movie_rating': 1, 'content_rating': 2}
# C:\Users\hp\AppData\Local\Temp\ipykernel_10420\1780935242.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data.loc[:, 'PeopleVote_winsorized'] = winsorize(cleaned_data['PeopleVote'], limits=[0.01, 0.01]).copy()
# C:\Users\hp\AppData\Local\Temp\ipykernel_10420\1780935242.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# # Visiulization

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

movies_df = pd.DataFrame(concatenated_dataset)

movies_df.head()

# Plotting the distribution of ratings
plt.figure(figsize=(10, 6))
sns.histplot(movies_df['movie_rating'], kde=True, color='skyblue')
plt.title('Distribution of Movie Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# Plotting the count of movies per year
plt.figure(figsize=(12, 6))
sns.countplot(x='Year', data=movies_df, palette='muted')
plt.title('Number of Movies Released Each Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# Plotting the count of movies per genre
plt.figure(figsize=(12, 6))
sns.countplot(y='Genre', data=movies_df, palette='muted', order=movies_df['Genre'].value_counts().index)
plt.title('Number of Movies in Each Genre')
plt.xlabel('Count')
plt.ylabel('Genre')
plt.show()

# Distribution of PeopleVote
plt.subplot(2, 2, 2)
plt.hist(people_votes, bins=15, color='coral')
plt.title('Distribution of PeopleVote')
plt.xlabel('PeopleVote')
plt.ylabel('Frequency')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 36
#      34 # Distribution of PeopleVote
#      35 plt.subplot(2, 2, 2)
# ---> 36 plt.hist(people_votes, bins=15, color='coral')
#      37 plt.title('Distribution of PeopleVote')
#      38 plt.xlabel('PeopleVote')
#
# NameError: name 'people_votes' is not defined

# %% [markdown]
# # feature engineerin

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer


df['Genre'] = df['Genre'].fillna('')
df['Actor'] = df['Actor'].fillna('')
df['Director'] = df['Director'].fillna('')


combined_features = (df['Genre'].str.lower() + ' ' + 
                     df['Actor'].str.lower() + ' ' + 
                     df['Director'].str.lower())


tfidf = TfidfVectorizer(stop_words='english')


tfidf_matrix = tfidf.fit_transform(combined_features)

print(tfidf_matrix.shape)
# Out:
# (27, 76)

# %% [markdown]
# # Similarity Calculation

# %%
from sklearn.metrics.pairwise import linear_kernel


cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %% [markdown]
# # Recommendation

# %%
def recommend_movies(movie_title, data, cosine_sim):
    movie_subset = data[data['MovieName'] == movie_title]
    if len(movie_subset) == 0:
        return "Movie not found in the dataset."
    
    idx = movie_subset.index[0]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]  
    movie_indices = [i[0] for i in sim_scores]
    return data['MovieName'].iloc[movie_indices]

recommended_movies = recommend_movies('Ramayya Vasthavayya', df, cosine_sim)

# %%
recommended_movies
# Out:
# 5           Thanga Magan
# 20                Anjaan
# 21               Kaththi
# 6                  Theri
# 9                 Mersal
# 8         Janatha Garage
# 10          Rangasthalam
# 3     Attarintiki Daredi
# 22       S/O Satyamurthy
# 25         Irumbu Thirai
# Name: MovieName, dtype: object

# %% [markdown]
# # to find details of specific actor

# %%
actor_name = "Vishal"
actor_data = concatenated_dataset[concatenated_dataset['Actor'].str.contains(actor_name, case=False)]
print("Movies featuring", actor_name, ":")
print(actor_data[['MovieName', 'Director', 'Genre']])
# Out:
# Movies featuring Vishal :
#               MovieName       Director             Genre
# 25        Pandiya Naadu   Suseenthiran            Action
# 48                Jeeva   Suseenthiran             Drama
# 55        Mundaasupatti      Ram Kumar            Comedy
# 73   Indru Netru Naalai   R. Ravikumar            Comedy
# 150      Thupparivaalan        Myshkin            Action
# 224       Pandem Kodi 2  N. Linguswamy            Action
# 227          Raatchasan      Ram Kumar            Action
# 249       Irumbu Thirai   P.S. Mithran            Action
# 300              Ayogya   Venkat Mohan            Action
# 354       Irumbu Thirai   P.S. Mithran  Action, Thriller

# %% [markdown]
# # by its first letter

# %%
actors_with_a = concatenated_dataset[concatenated_dataset['Actor'].str.startswith(('V', 'v'))]
unique_actors_with_a = actors_with_a['Actor'].unique()
print("Actor names starting with 'V' or 'v':")
for actor in unique_actors_with_a:
    print(actor)
# Out:
# Actor names starting with 'V' or 'v':
# Vimal
# Vikram
# Vijay Sethupathi
# Vijay Antony
# Vikram Prabhu
# Vishal
# Vishnu Vishal
# Veera Bahu
# Vidharth
# Vijay Kumar
# Vaibhav Reddy
# Vinay Rai
# Varalaxmi Sarathkumar
# Vicky Anand
# Velu Prabhakaran
# Vetri
# Vijay Deverakonda
# Vikranth
# Vivek
# Venkatesh, Mahesh Babu
